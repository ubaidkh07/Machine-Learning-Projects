# %% [markdown]
# # Project : Mobile Price Prediction

# %% [markdown]
# **Import required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('/content/train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %% [markdown]
# **Statistical measures of the dataset**

# %%
df.describe(include='all')
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# **Checking missing values**

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
plt.scatter(df['ram'],df['price_range'])
plt.xlabel('Ram')
plt.ylabel('Price')
plt.title('Ram vs Price')
plt.show()

# %%
plt.scatter(df['battery_power'],df['price_range'])
plt.xlabel('Battery')
plt.ylabel('Price')
plt.title('Battery vs Price')
plt.show()

# %%
plt.scatter(df['price_range'],df['fc'])
plt.xlabel('Price')
plt.ylabel('Fuel Consumption')
plt.title('Price vs Fuel Consumption')
plt.show()

# %%
plt.scatter(df['price_range'],df['n_cores'])
plt.xlabel('Price')
plt.ylabel('Number of Cores')
plt.title('Price vs Number of Cores')
plt.show()

# %% [markdown]
# **Correlation of the data**

# %%
corr=df.corr()
corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %% [markdown]
# **Display Correlation of the data**

# %%
sns.heatmap(corr,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':7},cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# **Separating the Input features and target**

# %%
x=df.drop('price_range',axis=1)
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y=df['price_range']
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %% [markdown]
# **Feature selection**

# %%
corr_target=corr['price_range']
corr_target
# Out:
# battery_power    0.200723
# blue             0.020573
# clock_speed     -0.006606
# dual_sim         0.017444
# fc               0.021998
# four_g           0.014772
# int_memory       0.044435
# m_dep            0.000853
# mobile_wt       -0.030302
# n_cores          0.004399
# pc               0.033599
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# sc_h             0.022986
# sc_w             0.038711
# talk_time        0.021859
# three_g          0.023611
# touch_screen    -0.030411
# wifi             0.018785
# price_range      1.000000
# Name: price_range, dtype: float64

# %%
threshold=0.03
relevant_features=corr_target[abs(corr_target)>=threshold].index.tolist()
relevant_features
# Out:
# ['battery_power',
#  'int_memory',
#  'mobile_wt',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_w',
#  'touch_screen',
#  'price_range']

# %%
df.drop(df.columns.difference(relevant_features),axis=1,inplace=True)

# %%
x1=df.drop(['price_range'],axis=1)
x1
# Out:
#       battery_power  int_memory  mobile_wt  pc  px_height  px_width   ram  \
# 0               842           7        188   2         20       756  2549
# 1              1021          53        136   6        905      1988  2631
# 2               563          41        145   6       1263      1716  2603
# 3               615          10        131   9       1216      1786  2769
# 4              1821          44        141  14       1208      1212  1411
# ...             ...         ...        ...  ..        ...       ...   ...
# 1995            794           2        106  14       1222      1890   668
# 1996           1965          39        187   3        915      1965  2032
# 1997           1911          36        108   3        868      1632  3057
# 1998           1512          46        145   5        336       670   869
# 1999            510          45        168  16        483       754  3919
#
#       sc_w  touch_screen
# 0        7             0
# 1        3             1
# ...

# %% [markdown]
# **Repeat steps in test data**

# %%
fd=pd.read_csv('/content/test(2).csv')
fd
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
fd.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
fd.tail()
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
fd.shape
# Out:
# (1000, 21)

# %%
fd.dtypes
# Out:
# id                 int64
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# dtype: object

# %%
fd.isna().sum()
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %%
fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
fd.describe(include='all')
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# ...

# %%
v_c=fd[['ram','battery_power','fc','n_cores']]
for i in v_c:
  print(fd[i].value_counts())
  print('*'*100)
# Out:
# 1435    3
# 3816    3
# 1972    3
# 3386    3
# 2179    3
#        ..
# 3238    1
# 1266    1
# 1634    1
# 3208    1
# 1223    1
# Name: ram, Length: 872, dtype: int64
# ****************************************************************************************************
# 1074    5
# 1981    5
# 529     4
# 1745    4
# 1715    4
#        ..
# 1248    1
# 1392    1
# 1706    1
# 1297    1
# 1185    1
# Name: battery_power, Length: 721, dtype: int64
# ****************************************************************************************************
# 0     210
# 1     124
# 2      97
# 4      80
# 5      74
# 3      70
# 6      59
# 7      50
# 9      41
# 8      38
# 10     37
# 11     29
# 13     21
# 12     17
# 14     16
# 15     12
# 16     11
# 18     10
# 17      2
# 19      2
# Name: fc, dtype: int64
# ****************************************************************************************************
# 4    142
# 1    138
# 2    134
# 5    130
# 3    127
# 8    121
# ...

# %%
corr=fd.corr()
corr
# Out:
#                      id  battery_power      blue  clock_speed  dual_sim  \
# id             1.000000      -0.021511  0.000464     0.035917 -0.002721
# battery_power -0.021511       1.000000 -0.046610    -0.039075 -0.061171
# blue           0.000464      -0.046610  1.000000     0.034754 -0.011100
# clock_speed    0.035917      -0.039075  0.034754     1.000000 -0.012423
# dual_sim      -0.002721      -0.061171 -0.011100    -0.012423  1.000000
# fc             0.016934      -0.007846 -0.056063     0.010127  0.057606
# four_g         0.030921      -0.042520 -0.001169    -0.024665  0.024907
# int_memory    -0.014023       0.003751 -0.012416    -0.030487 -0.012158
# m_dep         -0.002794      -0.009065  0.018319     0.016995  0.021760
# mobile_wt     -0.007541      -0.047065  0.023513    -0.014107 -0.001734
# n_cores       -0.015935       0.025732  0.003283    -0.012247 -0.003129
# pc             0.001969       0.012847 -0.025247     0.047469  0.073936
# ...

# %%
sns.heatmap(corr,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':7},cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# **Remove unwanted columns**

# %%
fd.drop('id',axis=1,inplace=True)

# %%
fd.drop(fd.columns.difference(relevant_features),axis=1,inplace=True)
fd
# Out:
#      battery_power  int_memory  mobile_wt  pc  px_height  px_width   ram  \
# 0             1043           5        193  16        226      1412  3476
# 1              841          61        191  12        746       857  3895
# 2             1807          27        186   4       1270      1366  2396
# 3             1546          25         96  20        295      1752  3893
# 4             1434          49        108  18        749       810  1773
# ..             ...         ...        ...  ..        ...       ...   ...
# 995           1700          54        170  17        644       913  2121
# 996            609          13        186   2       1152      1632  1933
# 997           1185           8         80  12        477       825  1223
# 998           1533          50        171  12         38       832  2509
# 999           1270          35        140  19        457       608  2828
#
#      sc_w  touch_screen
# 0       7             1
# 1       0             0
# ...

# %% [markdown]
# **Model Creation**
# - DecisionTreeClassifier
# - KNeighborsClassifier
# - LogisticRegression

# %% [markdown]
# **DecisionTreeClassifier**

# %%
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x1,y)
y_pred=model.predict(fd)
y_pred
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 1, 2, 0, 3, 2, 0, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 0, 3, 3, 2, 0, 1, 1, 1,
#        2, 2, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 1, 3, 3, 0, 3, 0, 3, 1,
#        2, 0, 1, 2, 2, 0, 2, 1, 0, 2, 2, 3, 1, 0, 0, 3, 1, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 2, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 3, 3, 1, 0, 2,
#        1, 1, 3, 0, 1, 0, 3, 2, 1, 3, 1, 3, 2, 3, 3, 2, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 0, 0, 3, 0, 0, 0, 2, 0, 0, 2,
#        1, 0, 1, 2, 0, 0, 0, 1, 2, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 3, 1, 1, 3, 3, 3, 1, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 1, 3, 0, 1, 0, 2, 2, 1, 3, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 2, 3, 2, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 0, 2, 2, 1, 2,
#        3, 3, 3, 1, 1, 1, 2, 2, 2, 1, 3, 2, 0, 3, 0, 0, 2, 0, 0, 3, 2, 3,
# ...

# %% [markdown]
# **KNeighborsClassifier**

# %%
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x1,y)
y_pred=model.predict(fd)
y_pred
# Out:
# array([3, 3, 3, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 0, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 2, 0, 2, 1, 1,
#        1, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        2, 0, 1, 2, 2, 1, 2, 2, 1, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 2, 0, 2,
#        1, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 3, 2, 3, 3, 2, 2, 3, 2, 3, 0, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 1, 3, 1, 0, 2, 2,
#        3, 3, 1, 1, 3, 2, 3, 2, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 0, 2, 3, 1, 1, 3, 2, 1, 3, 0, 0, 2, 0, 0, 3, 3, 3,
# ...

# %% [markdown]
# **LogisticRegression**

# %%
model=LogisticRegression(max_iter=1000)
model.fit(x1,y)
y_pred=model.predict(fd)
y_pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([2, 3, 2, 3, 1, 2, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 1, 1, 2, 1, 1, 3,
#        1, 2, 3, 0, 3, 0, 3, 1, 2, 0, 3, 0, 0, 1, 3, 1, 3, 3, 0, 2, 0, 0,
#        0, 1, 1, 3, 1, 2, 2, 0, 2, 0, 3, 0, 3, 1, 1, 3, 3, 3, 1, 2, 0, 2,
#        1, 3, 1, 1, 1, 1, 2, 3, 2, 0, 3, 0, 2, 3, 0, 3, 3, 0, 2, 0, 3, 0,
#        3, 1, 1, 1, 3, 0, 2, 3, 0, 2, 1, 3, 3, 0, 0, 3, 1, 1, 1, 1, 3, 3,
#        3, 2, 1, 3, 3, 2, 3, 1, 3, 0, 0, 3, 3, 1, 1, 0, 3, 3, 2, 1, 0, 3,
# ...
